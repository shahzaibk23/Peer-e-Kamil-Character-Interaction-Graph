# %%
import networkx as nx
import matplotlib.pylab as plt

g = nx.read_edgelist("abcd.txt")
print(nx.info(g))

nx.draw_random(g, with_labels=False)
plt.show()
# Out:
# Name:
# Type: Graph
# Number of nodes: 62
# Number of edges: 68
# Average degree:   2.1935
